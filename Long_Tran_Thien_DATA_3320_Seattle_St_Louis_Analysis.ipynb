# %% [markdown]
# <a href="https://colab.research.google.com/github/longhtt/Seattle-Weather/blob/main/Long_Tran_Thien_DATA_3320_Seattle_St_Louis_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction

# %% [markdown]
# ##### $\rightarrow$ Provide a brief introduction to the purpose of this notebook.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid')
import missingno as msno

# %% [markdown]
# ## Load clean data

# %% [markdown]
# ##### $\rightarrow$ Load the clean data set from Github.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/longhtt/Seattle-Weather/main/clean_seattle_stl_weather.csv')

# %% [markdown]
# ##### $\rightarrow$ Review the contents of the data set.

# %%
df
# Out:
#             date     city  precipitation  day_of_year  day  month  year
# 0     2018-01-01      STL           0.00            1    1      1  2018
# 1     2018-01-02      STL           0.00            2    2      1  2018
# 2     2018-01-03      STL           0.00            3    3      1  2018
# 3     2018-01-04      STL           0.00            4    4      1  2018
# 4     2018-01-05      STL           0.00            5    5      1  2018
# ...          ...      ...            ...          ...  ...    ...   ...
# 3647  2022-12-27  Seattle           0.78          361   27     12  2022
# 3648  2022-12-28  Seattle           0.40          362   28     12  2022
# 3649  2022-12-29  Seattle           0.03          363   29     12  2022
# 3650  2022-12-30  Seattle           0.62          364   30     12  2022
# 3651  2022-12-31  Seattle           0.17          365   31     12  2022
#
# [3652 rows x 7 columns]

# %% [markdown]
# ## State your questions

# %% [markdown]
# The overall problem is to compare how much it rains in Seattle and St. Louis. To answer this general problem, you will need to ask specific questions about the data.

# %% [markdown]
# ##### $\rightarrow$ List your questions about the data that will help you solve the problem.

# %% [markdown]
# 1. How many months does it rain more in Seattle or St. Louis?
# 2. What is the greatest or average precipitation Seattle and St. Louis have each month or year

# %% [markdown]
# ## Analysis

# %% [markdown]
# Perform analyses necessary to answer the questions. You will likely start by trying many things, some of which are useful and some of which are not. Don't be afraid to try different analyses at first. You will edit your notebook to a clean version that retains only the essential components at the end of the project.

# %% [markdown]
# creating plots to answer the the question listed

# %%
monthly_plot = sns.catplot(kind='bar', data=df, x='month', y='precipitation', hue='city', errorbar = None)
monthly_plot.set_xticklabels(["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])

# %% [markdown]
# on average, we can see as the months changes St. Louis during the summer reachs its peak in avg. precipitation and drops during the winter, and the opposite happens for Seattle where Seattle has more precipitation during the Winter and drops in the Summer. Another detail to note is Seattle and St. Louis have differetst lowest drop points where Seattle drops down to 0.01 precipitation during the Summer while St. Louis only drops down to above 0.05 precipitation.

# %%
sns.barplot(data = df, x = 'year', y = 'precipitation', hue = 'city', errorbar = None)
# Out:
# <Axes: xlabel='year', ylabel='precipitation'>

# %% [markdown]
# using avg. precipitation each year plot, we can see that St. Louis has more precipitation 4 out of 5 years vs Seattle

# %% [markdown]
# ### Results for communication assignment

# %% [markdown]
# This file should clearly produce the graphs, tables, models, etc that appear in the communication assignment.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Provide a brief description of your conclusions.

# %% [markdown]
# depending on which graph we are looking, we can have different answers when answering the question: Which City rains more.
# using the first graph i would say that it would depened on the seaon. We can see clearly that in Seattle it rains more during Winter but St. Louis rain more during the Summer. If i was to say one of the cities rain more than it would be St. Louis that rains more because of looking at the second graph. the second graph clearly shows us an avg. precipitation per year for each city and St. Louis is larger than Seattle 4 out of the 5 years shown.
